# %%
from RungeKutteM import RungeKutteMethod
from AdamsM import adams_method
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from runge_rule import runge_rule
from CaushiM import eilerMethod
from runge_rule import runge_rule

# %%
delta = 10
r = 1
b = 8/3

# %%
def xfunc(t, x, y, z):
    return delta * (y - x)    
def yfunc(t, x, y, z):
    return x * (r - z) - y
def zfunc(t, x, y, z):
    return x * y - b * z

# %% [markdown]
# Эта функция строит график решений для 3 численных методов

# %%
def solving_with_graph(start_values: list, amount_of_points: int):
    k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, start_values, amount_of_points)
    a = np.linspace(0, 1, amount_of_points)
    my = []
    my1 = []
    my2 = []
    for i in range(len(k)): 
        my.append(k[i][1])
        my1.append(k[i][0])
        my2.append(k[i][2])

    plt.plot(a, my, color = 'orange')
    plt.plot(a, my1, color = 'green')
    plt.plot(a, my2, color = 'purple')
    plt.scatter(a,my, color = "green")
    plt.scatter(a, my1, color = 'black')
    plt.show()
    plt.close()

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

        # !!!
    ax.plot3D(my, my1, my2, 'gray')

    plt.show()

    k = eilerMethod([xfunc, yfunc, zfunc], 0, 1, start_values, amount_of_points)

    my = []
    my1 = []
    my2 = []
    for i in range(len(k)): 
        my.append(k[i][1])
        my1.append(k[i][0])
        my2.append(k[i][2])

    plt.plot(a, my, color = 'orange')
    plt.plot(a, my1, color = 'green')
    plt.plot(a, my2, color = 'purple')
    plt.scatter(a,my, color = "green")
    plt.scatter(a, my1, color = 'black')
    plt.show()
    plt.close()



    k = adams_method([xfunc, yfunc, zfunc], 0, 1, start_values, amount_of_points)

    my = []
    my1 = []
    my2 = []
    for i in range(len(k)): 
        my.append(k[i][1])
        my1.append(k[i][0])
        my2.append(k[i][2])

    plt.plot(a, my, color = 'orange')
    plt.plot(a, my1, color = 'green')
    plt.plot(a, my2, color = 'purple')
    plt.scatter(a,my, color = "green")
    plt.scatter(a, my1, color = 'black')
    plt.show()
    plt.close()

# %% [markdown]
# Тут видно, что при начальных значениях 0,0,0 решение системы будет тождестевнный 0. Потому что ни 1 из методов не может пройти это значение в силу того как они написаны. Поэтому далее будем использовать значения, приближенные к 0

# %%
solving_with_graph([0, 0, 0], 1280)

# %% [markdown]
# Тут видно, что метод Рунге Кутты для небольшого количества точек работает лучше, чем остальные. Поэтому все дальнейшие тесты я буду проводить на нём.

# %%
solving_with_graph([0.1, 0.1, 0.1], 128)

# %% [markdown]
# Также, я решил 1 из начальных значений поменять на 10, чтобы графики не сливались в процессе. И исследовать поведение параметров для этих значений

# %%
solving_with_graph([0.1, 10, 0.1], 128)

# %% [markdown]
# Теперь меняем значения параметров, оставляя начальные значения такими же. Как указано в учебнике, будем менять только r

# %%
r = 100
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = np.array([k[i][0] for i in range(len(k))])
my1 = np.array([k[i][1] for i in range(len(k))])
my2 = np.array([k[i][2] for i in range(len(k))])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(my, my1, my2, 'green')

plt.show()

# %%
r = 200
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(my, my1, my2, 'gray')

plt.show()

# %%
r = 300
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %%
r = 400
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %%
r = 500
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %%
r = 24.74
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %%
r = 13.926
k = RungeKutteMethod([xfunc, yfunc, zfunc], 0, 1, [0.1, 10, 0.1], 1280)
a = np.linspace(0, 1, 1280)
my = []
my1 = []
my2 = []
for i in range(len(k)): 
    my.append(k[i][1])
    my1.append(k[i][0])
    my2.append(k[i][2])

plt.plot(a, my, color = 'orange')
plt.plot(a, my1, color = 'green')
plt.plot(a, my2, color = 'purple')
plt.scatter(a,my, color = "green")
plt.scatter(a, my1, color = 'black')
plt.show()
plt.close()

# %% [markdown]
# Будем рассматривать систему на временном промежутке от 0 до 100. Параметры, как и стартовое значение будут варироваться. Их видно в коде, иногда я их буду указывать в markdownах

# %% [markdown]
# Рассмотрим систему, где 0 < r < 1. С начальными значениями

# %%
func = [xfunc, yfunc, zfunc]
start_values = [2, 3, -4]

# %%
eps = 1e-9
ru = runge_rule(RungeKutteMethod, func, 0, 100, start_values, eps) 
ei = runge_rule(eilerMethod, func, 0, 100, start_values, eps)
ad = runge_rule(adams_method, func, 0, 100, start_values, eps)
print(pd.DataFrame(ru))
# Out:
# [[-5.871058961834165, -5.87105896183416, 12.926000000000004, 10]]
# 3
# [-5.871058961834181, -5.871058961834191, 12.92599999999999]
# [[-5.871059034140803, -5.871059037516005, 12.926000060098596, 10]]
# 3
# [-5.871058961835298, -5.871058961835944, 12.925999999999908]
# [[-5.871058961834178, -5.8710589618341835, 12.926000000000007, 10]]
# 3
# [-5.871058961834183, -5.871058961834193, 12.925999999999997]
#           0         1       2             3
# 0 -5.871059 -5.871059  12.926  1.000000e+01
# 1 -5.871059 -5.871059  12.926  3.019807e-14

# %% [markdown]
# Проведя сравнение методов с помощью правила Рунге и на разных тестах. Я выяснил, что метод Рунге-Кутты наилучший для этой задачи в силу того, что остальные методы могут принимать значение +бесконечность даже для разбиений с достаточно большим количеством точек. Правило Рунге я не использовал в силу того, что для некоторых h, решение ведёт себя неадекватно. И удобнее подбирать количество точек самому

# %%
r = 1/10
k = RungeKutteMethod(func, 0, 100, start_values, 128000)
print(pd.DataFrame(k))
xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()
# Out:
#                    0             1             2
# 0       2.000000e+00  3.000000e+00 -4.000000e+00
# 1       2.007800e+00  3.004063e+00 -3.986980e+00
# 2       2.015572e+00  3.008128e+00 -3.973963e+00
# 3       2.023314e+00  3.012193e+00 -3.960948e+00
# 4       2.031028e+00  3.016259e+00 -3.947935e+00
# ...              ...           ...           ...
# 127995  2.187379e-39  1.992653e-39  4.917765e-78
# 127996  2.185858e-39  1.991267e-39  4.910929e-78
# 127997  2.184338e-39  1.989883e-39  4.904102e-78
# 127998  2.182820e-39  1.988499e-39  4.897285e-78
# 127999  2.181302e-39  1.987116e-39  4.890477e-78
#
# [128000 rows x 3 columns]

# %%
start_values = [-3, 1, 2]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

# %%
start_values = [200, 10, -20]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

# %%
start_values = [100, 10, -20]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

# %% [markdown]
# Для r принадлежит от 0 до 1. Решение системы является неустойчивым и сильно зависит от начальных данных. Получаются разные фигуры для разных входных данных. При этом, при изменении r, решение системы графически сильно не измнеится

# %% [markdown]
# возьмём r = 1. И внесем небольшой шум в данные. Из предыдущих наблюдений видно, что когда начальные значения достаточно маленькие, фигура получается простой. Поэтому и начальные значения возьмем близкие к единице по модулю

# %%
r = 9/10
start_values = [1.e-9, 0, 1]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

r = 1.01
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()


r = 1.1
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

r = 1
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

r = 0.99
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord)
plt.show()

# %% [markdown]
# Видно, что r = 1 - точка бифуркации. При небольших изменениях этого параметра, график принимает разный вид. То есть, решения системы уравнений сильно отличаются.

# %% [markdown]
# Рассмотрим r в промежутке от 1 до 13,926

# %%
r = 13
start_values = [-1.e-16, -1.e-16, -1.e-16]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D((b*(r-1))**(1/2), (b*(r-1))**(1/2), r-1, color = 'green')
ax.scatter3D(-(b*(r-1))**(1/2), -(b*(r-1))**(1/2), r-1, color = 'green')

# %%
r = 13
start_values = [1.e-16, 1.e-16, 1.e-16]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D((b*(r-1))**(1/2), (b*(r-1))**(1/2), r-1, color = 'green')
ax.scatter3D(-(b*(r-1))**(1/2), -(b*(r-1))**(1/2), r-1, color = 'green')

# %%
r = 5
start_values = [1.e-16, -1.e-16, -1.e-16]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D((b*(r-1))**(1/2), (b*(r-1))**(1/2), r-1, color = 'green')
ax.scatter3D(-(b*(r-1))**(1/2), -(b*(r-1))**(1/2), r-1, color = 'green')

# %% [markdown]
# Видно, что при r, лежащем в этом промежутке, решение совпадает с одной из аналитически-выведенных точек. При всех отрицательных начальных значениях, будет совпадать с отрицательными точками. При хотя бы 1 положительном, будет совпадать с положительной точкой. То есть 1 из аналитических решений будет являться неподвижной точкой

# %% [markdown]
# Рассмотрим подробно случай r = 13,926. Видно, что в этом случае даже при большом изменении начальных данных. Решение всё равно имеет вид, похожий на изначальный

# %%
r = 13.926
start_values = [1.e-16, 1.e-16, 1.e-16]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')
ax.scatter3D(xcoord, ycoord, zcoord, color = 'green')


r = 13.926
start_values = [10, 10, 10]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)
xcoord = []
ycoord = []
zcoord = []

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]



    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'red')
# ax.scatter3D(xcoord, ycoord, zcoord, 'green')
plt.show()

# %% [markdown]
# Теперь рассмотрим r = 24,74. Видно, что для r = 24.74, Решение почти не зависит от начальных значений, то есть является устойчивым.

# %%
r = 24.74
start_values = [1.e-16, 1.e-16, 1.e-16]
k = RungeKutteMethod(func, 0, 1, start_values, 128000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')



r = 24.74
start_values = [10, 10, 10]
k = RungeKutteMethod(func, 0, 100, start_values, 128000)
xcoord = []
ycoord = []
zcoord = []

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]



    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'red')
# ax.scatter3D(xcoord, ycoord, zcoord, 'green')
plt.show()

# %% [markdown]
# Рассмотрим 24.74 < r < 148.8

# %% [markdown]
# Интересно, что при изменении промежутка, график будет иметь тот же вид. Таким образом, я нашел положение равновесия, где решение не меняется в зависимости от времени

# %%
r = 28
start_values = [1000, -600, -400]
k = RungeKutteMethod(func, 0, 1000, start_values, 6280000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')

# %%
r = 28
start_values = [1000, -600, -400]
k = RungeKutteMethod(func, 0, 1, start_values, 12800)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')

# %% [markdown]
# Теперь рассмотрим 148.8 < r < 500. Тут, на самом деле, тоже видно, что при изменении времени, решение не поменяется. Поэтому это тоже положение равновесия

# %%
r = 300
start_values = [1, -1, 1]
k = RungeKutteMethod(func, 0, 1000, start_values, 1280000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'gray')



start_values = [1.1e-3, -1.1e-3, 1.1e-3]
k = RungeKutteMethod(func, 0, 100, start_values, 1280000)

xcoord = [k[i][0] for i in range(len(k))]
ycoord = [k[i][1] for i in range(len(k))]
zcoord = [k[i][2] for i in range(len(k))]


    # !!!
ax.plot3D(xcoord, ycoord, zcoord, 'green')

# %% [markdown]
# Таким образом, я посмотрел поведение системы в зависимости от параметра r
